# %%
import chromadb
client = chromadb.Client()

# %%
collection = client.create_collection("news")
# Out:
# {'deleted': 3}

# %%
collection.add(
    ids=["id1", "id2", "id3", "id4"],
    documents=[
        "Apple is leading in a smart phone game with iPhone sales up by 35%",
        "Tesla booked a minor profit of 1 billion $ in Q2",
        "Apples are high in fiber, vitamin C, and various antioxidants",
        "SpaceX got NASA contract worth 10 billion $",
    ]
)

# %%
results = collection.query(
    query_texts=["This is a query related to Elon Musk"],
    n_results=2
)
print(results)
# Out:
# {'ids': [['id2', 'id4']], 'embeddings': None, 'documents': [['Tesla booked a minor profit of 1 billion $ in Q2', 'SpaceX got NASA contract worth 10 billion $']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.5166926383972168, 1.5598335266113281]]}

# %%
results = collection.query(
    query_texts=["I love iPad"],
    n_results=2
)
print(results)
# Out:
# {'ids': [['id1', 'id3']], 'embeddings': None, 'documents': [['Apple is leading in a smart phone game with iPhone sales up by 35%', 'Apples are high in fiber, vitamin C, and various antioxidants']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.4372706413269043, 1.669586181640625]]}

# %%
results = collection.query(
    query_texts=["Tips for improving health"],
    n_results=2
)
print(results)
# Out:
# {'ids': [['id3', 'id1']], 'embeddings': None, 'documents': [['Apples are high in fiber, vitamin C, and various antioxidants', 'Apple is leading in a smart phone game with iPhone sales up by 35%']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.5245025157928467, 1.916359543800354]]}
